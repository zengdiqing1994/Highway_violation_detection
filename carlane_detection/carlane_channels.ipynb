# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
import math
from scipy import optimize
# %matplotlib inline

# %%
img1 = mpimg.imread('D:/python_code/RGB/R_channel.jpg')
img2 = mpimg.imread('D:/python_code/RGB/G_channel.jpg')
img3 = mpimg.imread('D:/python_code/RGB/B_channel.jpg')
plt.subplot(2,2,1)
plt.imshow(img1,)
# plt.figure(figsize=(20,10))
fig = plt.gcf()
fig.set_size_inches(16.5, 12.5)
plt.title('R_channel'),plt.xticks([]), plt.yticks([])

plt.subplot(2,2,2)
plt.imshow(img2,)
# plt.figure(figsize=(20,10))
fig = plt.gcf()
fig.set_size_inches(16.5, 12.5)
plt.title('G_channel'),plt.xticks([]), plt.yticks([])

plt.subplot(2,2,3)
plt.imshow(img3,)
# plt.figure(figsize=(20,10))
fig = plt.gcf()
fig.set_size_inches(16.5, 12.5)
plt.title('B_channel'),plt.xticks([]), plt.yticks([])

img = mpimg.imread('2.jpg')
img4 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.subplot(2,2,4)
plt.imshow(img4,'gray')
# plt.figure(figsize=(20,10))
fig = plt.gcf()
fig.set_size_inches(16.5, 12.5)
plt.title('Gray_img'),plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5,1,'Gray_img'),
#  ([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
ret1,img1 = cv2.threshold(img1,145,255,cv2.THRESH_BINARY)
plt.subplot(2,2,1)
plt.imshow(img1, "gray")
fig = plt.gcf()
fig.set_size_inches(16.5, 12.5)
plt.title("OTSU,threshold is " + str(ret1)+"  R_channel"), plt.xticks([]), plt.yticks([])

ret1,img2 = cv2.threshold(img2,145,255,cv2.THRESH_BINARY)
plt.subplot(2,2,2)
plt.imshow(img2, "gray")
fig = plt.gcf()
fig.set_size_inches(16.5, 12.5)
plt.title("OTSU,threshold is " + str(ret1)+"  G_channel"), plt.xticks([]), plt.yticks([])

ret1,img3 = cv2.threshold(img3,145,255,cv2.THRESH_BINARY)
plt.subplot(2,2,3)
plt.imshow(img3, "gray")
fig = plt.gcf()
fig.set_size_inches(16.5, 12.5)
plt.title("OTSU,threshold is " + str(ret1)+"  B_channel"), plt.xticks([]), plt.yticks([])

ret1,img4 = cv2.threshold(img4,145,255,cv2.THRESH_BINARY)
plt.subplot(2,2,4)
plt.imshow(img4, "gray")
fig = plt.gcf()
fig.set_size_inches(16.5, 12.5)
plt.title("OTSU,threshold is " + str(ret1)+"  Gray"), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5,1,'OTSU,threshold is 145.0  Gray'),
#  ([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
def weighted_img(img, initial_img, α=0.5, β=0.5, λ=0.):
    """
    `img` is the output of the hough_lines(), An image with lines drawn on it.
    Should be a blank image (all black) with lines drawn on it.
    
    `initial_img` should be the image before any processing.
    
    The result image is computed as follows:
    
    initial_img * α + img * β + λ
    NOTE: initial_img and img must be the same shape!
    """
    return cv2.addWeighted(img3, α, img1, β, λ)
mix = weighted_img(img3,img1,α=0.5, β=0.5, λ=0.)
plt.imshow(mix,'gray')

# %%
ret1,th1 = cv2.threshold(mix,145,255,cv2.THRESH_BINARY)
plt.subplot(2,2,1)
plt.imshow(th1,'gray')
fig = plt.gcf()
fig.set_size_inches(16.5, 12.5)
plt.title("B+R_channel_mix "+"threshold is " + str(ret1)),plt.xticks([]),plt.yticks([])
# Out:
# (Text(0.5,1,'B+R_channel_mix threshold is 145.0'),
#  ([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))
